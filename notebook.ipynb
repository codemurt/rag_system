# %%
# !pip install -q langchain langchain-docling langchain-community langchain-huggingface
# !pip install -q unsloth transformers torch accelerate docling
# !pip install -q chromadb sentence-transformers
# !pip install -q python-dotenv pypdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 57.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.1/158.1 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.1/86.1 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 58.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 44.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 75.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.0/253.0 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 48.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.7/73.7 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 42.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 24.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 26.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.3/172.3 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 25.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 44.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.9/292.9 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.8/272.8 kB 21.5 MB/s eta 0:00:00
#   Building wheel for pylatexenc (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.5/297.5 kB 27.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 19.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 376.2/376.2 kB 31.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 16.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 MB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 18.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.12.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 7.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.5/19.5 MB 88.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 94.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 27.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.8/65.8 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 kB 6.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.5/118.5 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.2/196.2 kB 19.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.2/71.2 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 37.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.9/319.9 kB 31.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 84.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 453.1/453.1 kB 39.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 8.7 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# unsloth-zoo 2025.7.4 requires protobuf<4.0.0, but you have protobuf 5.29.5 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.5/305.5 kB 20.2 MB/s eta 0:00:00

# %%
import os
import torch
from pathlib import Path
from typing import List, Dict, Any, Union
import json
import logging

from langchain_docling import DoclingLoader
from langchain_core.prompts import PromptTemplate
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain_community.vectorstores.utils import filter_complex_metadata
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.schema import Document
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM, T5ForConditionalGeneration, T5Tokenizer
from langchain_community.llms import HuggingFacePipeline
from langchain_community.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

from docling.datamodel import vlm_model_specs
from docling.datamodel.base_models import InputFormat
from docling.datamodel.pipeline_options import VlmPipelineOptions
from docling.document_converter import DocumentConverter, PdfFormatOption
from docling.pipeline.vlm_pipeline import VlmPipeline

# %%
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.StreamHandler(),
        logging.FileHandler('rag_system.log', encoding='utf-8')
    ]
)
logger = logging.getLogger(__name__)

os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
def clean_metadata(metadata: Dict[str, Any]) -> Dict[str, Union[str, int, float, bool, None]]:
    """
    Очищает метаданные от сложных структур для совместимости с Chroma.

    Args:
        metadata: Исходные метаданные

    Returns:
        Очищенные метаданные
    """
    cleaned = {}

    for key, value in metadata.items():
        if isinstance(value, (str, int, float, bool, type(None))):
            cleaned[key] = value
        elif isinstance(value, dict):
            if key == 'dl_meta' and isinstance(value, dict):
                if 'doc_items' in value and isinstance(value['doc_items'], list):
                    for item in value['doc_items']:
                        if isinstance(item, dict) and 'prov' in item:
                            prov_list = item.get('prov', [])
                            if prov_list and isinstance(prov_list[0], dict):
                                page_no = prov_list[0].get('page_no')
                                if page_no:
                                    cleaned['page_number'] = page_no
                                    break

                if 'headings' in value and isinstance(value['headings'], list):
                    if value['headings']:
                        cleaned['section'] = str(value['headings'][0])

                if 'origin' in value and isinstance(value['origin'], dict):
                    filename = value['origin'].get('filename')
                    if filename:
                        cleaned['source'] = filename
            else:
                cleaned[key] = str(value)
        elif isinstance(value, list):
            if value and all(isinstance(item, (str, int, float)) for item in value):
                cleaned[key] = ', '.join(str(item) for item in value)
            else:
                cleaned[key] = str(value)
        else:
            cleaned[key] = str(value)

    return cleaned

# %%
class RAG:
    """
    Универсальная RAG система для работы с технической документацией.
    Поддерживает русский язык, OCR и различные форматы документов.
    """

    def __init__(
        self,
        model_id: str = "unsloth/Llama-3.2-1B-Instruct",
        embed_model_id: str = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2",
        chunk_size: int = 512,
        chunk_overlap: int = 50,
        device: str = "cuda" if torch.cuda.is_available() else "cpu"
    ):
        """
        Инициализация RAG системы.

        Args:
            model_id: ID модели для генерации ответов
            embed_model_id: ID модели для эмбеддингов (мультиязычная)
            chunk_size: Размер чанков документа
            chunk_overlap: Перекрытие между чанками
            device: Устройство для вычислений
        """
        self.logger = logging.getLogger(self.__class__.__name__)
        self.model_id = model_id
        self.embed_model_id = embed_model_id
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        self.device = device

        self._init_llm()
        self._init_embeddings()
        self.vectorstore = None
        self.retriever = None

    def _init_llm(self):
        """Инициализация языковой модели."""
        self.logger.info(f"Загрузка модели {self.model_id}...")

        tokenizer = AutoTokenizer.from_pretrained(self.model_id, trust_remote_code=True)

        if tokenizer.pad_token is None:
            tokenizer.pad_token = tokenizer.eos_token

        model = AutoModelForCausalLM.from_pretrained(
            self.model_id,
            torch_dtype=torch.bfloat16 if self.device == "cuda" else torch.float32,
            device_map="auto" if self.device == "cuda" else None,
            trust_remote_code=True,
            low_cpu_mem_usage=True
        )

        pipe = pipeline(
            "text-generation",
            model=model,
            tokenizer=tokenizer,
            max_new_tokens=512,
            temperature=0.1,
            top_p=0.95,
            repetition_penalty=1.15,
            do_sample=True,
            pad_token_id=tokenizer.pad_token_id,
            truncation=True,
            max_length=2048
        )

        self.llm = HuggingFacePipeline(pipeline=pipe)
        self.logger.info("Модель загружена успешно!")


    def _init_embeddings(self):
        """Инициализация модели эмбеддингов."""
        self.logger.info(f"Загрузка модели эмбеддингов {self.embed_model_id}...")
        self.embeddings = HuggingFaceEmbeddings(
            model_name=self.embed_model_id,
            model_kwargs={'device': self.device}
        )
        self.logger.info("Модель эмбеддингов загружена успешно!")

    def load_document(self, file_path: str | List[str]) -> List[Any]:
        """
        Загрузка и обработка документов с использованием Docling.

        Args:
            file_path: Путь к файлу или список путей

        Returns:
            Список документов LangChain
        """
        if isinstance(file_path, str):
            file_path = [file_path]

        self.logger.info(f"Загрузка документов с VLM: {file_path}")

        try:
            converter = DocumentConverter(
                format_options={
                    InputFormat.PDF: PdfFormatOption(
                        pipeline_cls=VlmPipeline,
                    ),
                }
            )

            all_docs = []

            for path in file_path:
                self.logger.info(f"Обработка файла: {path}")

                result = converter.convert(source=path)
                doc = result.document

                markdown_content = doc.export_to_markdown()

                metadata = {
                    'source': path,
                    'filename': Path(path).name,
                    'format': 'pdf',
                    'converter': 'VLM Docling'
                }

                if hasattr(doc, 'metadata') and doc.metadata:
                    for key, value in doc.metadata.items():
                        if isinstance(value, (str, int, float, bool)):
                            metadata[key] = value

                sections = markdown_content.split('\n\n')

                for i, section in enumerate(sections):
                    if section.strip():
                        section_metadata = metadata.copy()
                        section_metadata['section_index'] = i

                        lines = section.strip().split('\n')
                        if lines and lines[0].startswith('#'):
                            section_metadata['section'] = lines[0].strip('#').strip()

                        langchain_doc = Document(
                            page_content=section.strip(),
                            metadata=section_metadata
                        )
                        all_docs.append(langchain_doc)

            self.logger.info(f"Загружено {len(all_docs)} секций из VLM Docling")

            cleaned_docs = []
            for doc in all_docs:
                cleaned_metadata = clean_metadata(doc.metadata)
                cleaned_doc = Document(
                    page_content=doc.page_content,
                    metadata=cleaned_metadata
                )
                cleaned_docs.append(cleaned_doc)

            text_splitter = RecursiveCharacterTextSplitter(
                chunk_size=self.chunk_size,
                chunk_overlap=self.chunk_overlap,
                length_function=len,
                separators=["\n\n", "\n", ".", " ", ""]
            )

            chunked_docs = []
            for doc in cleaned_docs:
                if len(doc.page_content) < 50:
                    continue

                chunks = text_splitter.split_text(doc.page_content)
                for i, chunk in enumerate(chunks):
                    chunk_metadata = doc.metadata.copy()
                    chunk_metadata['chunk_index'] = i
                    chunk_metadata['total_chunks'] = len(chunks)

                    chunked_docs.append(Document(
                        page_content=chunk,
                        metadata=chunk_metadata
                    ))

            self.logger.info(f"Создано {len(chunked_docs)} чанков документов")
            return chunked_docs

        except Exception as e:
            self.logger.error(f"Ошибка при загрузке через VLM Docling: {e}")
            self.logger.warning("Используем альтернативный загрузчик...")

            all_docs = []
            for path in file_path:
                try:
                    loader = PyPDFLoader(path)
                    docs = loader.load()

                    text_splitter = RecursiveCharacterTextSplitter(
                        chunk_size=self.chunk_size,
                        chunk_overlap=self.chunk_overlap
                    )

                    split_docs = text_splitter.split_documents(docs)
                    all_docs.extend(split_docs)

                except Exception as e2:
                    self.logger.error(f"Ошибка при загрузке {path}: {e2}")

            self.logger.info(f"Загружено {len(all_docs)} чанков через PyPDF")
            return all_docs


    def create_index(self, documents: List[Any], collection_name: str = "universal_rag"):
        """
        Создание векторного индекса из документов.

        Args:
            documents: Список документов LangChain
            collection_name: Название коллекции в векторной БД
        """
        self.logger.info("Создание векторного индекса...")

        filtered_docs = filter_complex_metadata(documents)

        self.vectorstore = Chroma.from_documents(
            documents=filtered_docs,
            embedding=self.embeddings,
            collection_name=collection_name,
            persist_directory="./chroma_db"
        )

        self.retriever = self.vectorstore.as_retriever(
            search_type="similarity",
            search_kwargs={"k": 5}
        )

        self.logger.info("Индекс создан успешно!")

    def _create_prompt_template(self) -> PromptTemplate:
        """Создание шаблона промпта для RAG."""
        template = """Ты - помощник, отвечающий на вопросы строго на основе предоставленного контекста.

        Контекст из документации:
        {context}

        Вопрос пользователя: {question}

        Инструкции:
        1. Отвечай ТОЛЬКО на основе информации из контекста
        2. Если информация отсутствует в контексте, честно скажи "Информация не найдена в документе"
        3. Если вопрос не относится к теме документа, скажи "Вопрос не относится к содержанию документа"
        4. Указывай источники информации (номера страниц, если доступны)
        5. Отвечай на том же языке, на котором задан вопрос

        Ответ:"""

        return PromptTemplate(
            template=template,
            input_variables=["context", "question"]
        )

    def answer_question(self, question: str, return_sources: bool = True) -> Dict[str, Any]:
        """
        Ответ на вопрос с использованием RAG.

        Args:
            question: Вопрос пользователя
            return_sources: Возвращать ли источники

        Returns:
            Словарь с ответом и метаданными
        """
        if not self.retriever:
            raise ValueError("Индекс не создан. Сначала загрузите документы и создайте индекс.")

        relevant_docs = self.retriever.get_relevant_documents(question)

        if not relevant_docs:
            return {
                "answer": "Информация не найдена в документе",
                "sources": [],
                "relevant_chunks": []
            }

        prompt = self._create_prompt_template()

        context_parts = []
        sources = []

        for i, doc in enumerate(relevant_docs):
            context_parts.append(f"[Фрагмент {i+1}]:\n{doc.page_content}")

            metadata = doc.metadata
            source_info = {
                "chunk_id": i + 1,
                "content": doc.page_content[:200] + "..." if len(doc.page_content) > 200 else doc.page_content
            }

            for page_key in ['page_number', 'page', 'page_no']:
                if page_key in metadata:
                    source_info['page_no'] = metadata[page_key]
                    break

            if 'section' in metadata:
                source_info['section'] = metadata['section']

            sources.append(source_info)

        context = "\n\n".join(context_parts)

        try:
            formatted_prompt = prompt.format(context=context, question=question)
            answer = self.llm.invoke(formatted_prompt)

            if isinstance(answer, str):
                answer = answer.strip()
                if "Ответ:" in answer:
                    answer = answer.split("Ответ:")[-1].strip()

        except Exception as e:
            self.logger.error(f"Ошибка при генерации ответа: {e}")
            answer = "Произошла ошибка при генерации ответа"

        result = {
            "answer": answer,
            "question": question,
            "sources": sources if return_sources else [],
            "relevant_chunks": [doc.page_content for doc in relevant_docs] if return_sources else []
        }

        return result

    def process_questions(self, questions: List[str]) -> List[Dict[str, Any]]:
        """
        Обработка списка вопросов.

        Args:
            questions: Список вопросов

        Returns:
            Список ответов с метаданными
        """
        results = []

        for i, question in enumerate(questions, 1):
            self.logger.info(f"Обработка вопроса {i}/{len(questions)}: {question}")
            result = self.answer_question(question)
            results.append(result)

            answer_preview = result['answer'][:200] + "..." if len(result['answer']) > 200 else result['answer']
            self.logger.info(f"Ответ: {answer_preview}")

        return results

# %%
logger.info("Инициализация RAG системы")
rag_system = RAG()

pdf_path = "/content/Руководство по насосам шламовым 4 DY -AHF.pdf"

logger.info("Загрузка документа")
documents = rag_system.load_document(pdf_path)
logger.debug(f"Загружено документов: {len(documents)}")

logger.info("Создание индекса")
rag_system.create_index(documents)

test_questions = [
    "Какой объём смазки (л) требуется для подшипниковой рамы DY?",
    "Укажите кинематическую вязкость рекомендованного масла при 40°C для роликовых подшипников.",
    "Назовите заводскую смазку, рекомендованную для камеры центробежного уплотнения.",
    "Приведите номер телефона сервисной линии для клиентов в Финляндии.",
    "Какова ширина ремня (мм), указанная для диапазона шкивов 170-224 мм (профиль SPB)?",
    # "Перечислите три основных требования техники безопасности при подъёме насоса с вертикальным приводом (CV).",
    # "Опишите процедуру проверки уровня масла в подшипниковом узле.",
    # "Какой класс NLGI указан для пластичной смазки камеры центробежного уплотнения?",
    # "Какой индекс вязкости DIN-ISO 2909 указан для рекомендуемого масла подшипников?",
    # "На сколько литров объём смазки рамы FFY превышает объём рамы BY?",
    # "Согласно схеме LD002-RUS WP8, какой тип стропа рекомендован?",
    # "Сформируйте краткую инструкцию 'Ежедневное ТО + подъём' (≤100 слов)."
]

logger.info("Ответы на вопросы")
results = rag_system.process_questions(test_questions)

logger.info("Подробные результаты")
for i, result in enumerate(results, 1):
    logger.info(f"Вопрос {i}: {result['question']}")
    logger.info(f"Ответ: {result['answer']}")

    if result['sources']:
        logger.info("Источники:")
        for source in result['sources']:
            logger.info(f"  - Фрагмент {source['chunk_id']}")
            if 'page_no' in source:
                logger.info(f"    Страница: {source['page_no']}")
            if 'section' in source:
                logger.info(f"    Секция: {source['section']}")
            logger.info(f"    Текст: {source['content']}")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/894 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Device set to use cuda:0
# /tmp/ipython-input-5-138202443.py:68: LangChainDeprecationWarning: The class `HuggingFacePipeline` was deprecated in LangChain 0.0.37 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFacePipeline``.
#   self.llm = HuggingFacePipeline(pipeline=pipe)
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# /tmp/ipython-input-5-138202443.py:269: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   relevant_docs = self.retriever.get_relevant_documents(question)

# %%
results
# Out:
# [{'answer': 'Вопрос не относится к содержанию документа. \n\n        Итак, нам нужно найти информацию о смазке для подшипниковой рамы DY. \n\n        Фрагмент 1: Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмера рамы насоса:\n\n    [Фрагмент 1]\n    \n   ... (информация)\n\n    4. На этом этапе величина нюдфота будет первый ад_accessibleный значение. Для установления величины люфта в пределах нормул, удалите несколько прокладок с приводной части вала.\n    \n   ... (информация)\n\n    6. После повторной регулировки еще раз замерьте люfts вала. Производите регулировку до тех пор, пока величина люфта ни окажется в пределах значений, указанных в таблице "ДОПУСТИМЫЕ" значения Люфта.\n\n   ... (информация)\n\n        Вопрос не относится к содержанию документа. \n\n        Итак, нам нужно найти информацию о смазке для подшипниковой рамы DY. \n\n        Фрагмент 1: Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмера рамы насоса:\n\n    [Фрагмент 1]\n\n   ... (информация)\n\n    4. На этом этапе величина нюдфота будет первый адaccessibleный значение. Для установления величины люфта в пределах нормул, удалите несколько прокладок с приводной части вала.\n\n   ... (информация)\n\n    6. После повторной регулировки еще раз замерьте люfts вала. Производите регулировку до тех пор, пока величина люфта ни окажется в пределах значений, указанных в таблице "ДОПУСТИМЫЕ" значения Люфта.\n\n   ... (информация)\n\n        Вопрос не относится к содержанию документа. \n\n        Итак, нам нужно найти информацию о смазке для подшипниковой рамы DY. \n\n        Фрагмент 1: Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмер',
#   'question': 'Какой объём смазки (л) требуется для подшипниковой рамы DY?',
#   'sources': [{'chunk_id': 1,
#     'content': 'Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмера рамы насоса:'},
#    {'chunk_id': 2,
#     'content': 'Между станином и блоком фундамента продолжите железные или стальные прокладки на небольшом расстоянии друг от фуга. Для того, чтобы установить раму без перекоса, воспондутьесть таким количеством прокл...'},
#    {'chunk_id': 3,
#     'content': '- 4. На этом этапе величина нюдфота будет первый адоступные значения. Для установления величины люфта в пределах нормул, удалите несколько прокладок с приводной части вала.\n- 5. После удаления проклад...'},
#    {'chunk_id': 4,
#     'content': 'Установка внутренней части конического подшипника со стороны привода'},
#    {'chunk_id': 5,
#     'content': '- 1. Подшипниковые узлы А, В, С, D должны занимать горзонитандье положение, при этом корпус следует жестко зафиксировать с помощью верстачных тисков.\n- Подшипниковые узлы Е, F, G должны находиться в в...'}],
#   'relevant_chunks': ['Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмера рамы насоса:',
#    'Между станином и блоком фундамента продолжите железные или стальные прокладки на небольшом расстоянии друг от фуга. Для того, чтобы установить раму без перекоса, воспондутьесть таким количеством прокладкой, како будет необходимо. Дополнительно следует положить по данной продолжидаке с кадкой стороны неэкраного болита. Проверьете уровневан установки рамы и отретуйте регистор по сперинбенность белое 0,05 мм на каждые 254 мм. Это делается при помощи регулировочных прокладок',
#    '- 4. На этом этапе величина нюдфота будет первый адоступные значения. Для установления величины люфта в пределах нормул, удалите несколько прокладок с приводной части вала.\n- 5. После удаления прокладок установите заново торцевую крышку и затяните винты.\n- 6. После повторной регулировки еще раз замерьте люфт вала. Производите регулировку до тех пор, пока величина люфта ни окажется в пределах значений, указанных в таблице "ДОПУСТИМЫЕ" значения Люфта".',
#    'Установка внутренней части конического подшипника со стороны привода',
#    '- 1. Подшипниковые узлы А, В, С, D должны занимать горзонитандье положение, при этом корпус следует жестко зафиксировать с помощью верстачных тисков.\n- Подшипниковые узлы Е, F, G должны находиться в вертикальном положении, при этом корпус следует жестко зафиксировать на положении, пречез которую можно пропустить конец вала.\n- 2. Закрепите кронштейн идиматка на торцевой крышке с торновы рабочего колеса и установите ножуй индикатора на торцева вала.']},
#  {'answer': 'В',
#   'question': 'Укажите кинематическую вязкость рекомендованного масла при 40°C для роликовых подшипников.',
#   'sources': [{'chunk_id': 1,
#     'content': 'Предварительно нагреите подшипники, погрузь их в чистое масло при температуре около 100°C. Убедитесь, что подшипним не касаются дна контентера.'},
#    {'chunk_id': 2,
#     'content': 'Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмера рамы насоса:'},
#    {'chunk_id': 3,
#     'content': 'Правильное натяжение ременд лередации беспочевай идопильн. срок службы, как ременд, так и роликовых подпишкинов. Натягивая ремень следует вращать придводя дго, чтобы натяжение было равномерным. Высоки...'},
#    {'chunk_id': 4,
#     'content': 'Ежедневно проверите уровень масла, он должен находиться между нижней и верхней отметками на шуле. Вал насоса должен располагаться горизонтально. При необходимости доливайте масло через вентиляционный ...'},
#    {'chunk_id': 5,
#     'content': 'Смажтье обычным солдомол обработанные поверхности станины, на которые будет опираться подшипниковый узел. Это поможет при установке рабочего колеса во время окончательной сборки.'}],
#   'relevant_chunks': ['Предварительно нагреите подшипники, погрузь их в чистое масло при температуре около 100°C. Убедитесь, что подшипним не касаются дна контентера.',
#    'Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмера рамы насоса:',
#    'Правильное натяжение ременд лередации беспочевай идопильн. срок службы, как ременд, так и роликовых подпишкинов. Натягивая ремень следует вращать придводя дго, чтобы натяжение было равномерным. Высокий КПД клиноременной передачи, соответствующий требованиями, предъявляемыми соорвеннему оборудованию, может быть достигнут только при правильному натяжении ременд. Для проверки правильности натяжения ремости рисунок 2 и выполните операции, приведенные далее.',
#    'Ежедневно проверите уровень масла, он должен находиться между нижней и верхней отметками на шуле. Вал насоса должен располагаться горизонтально. При необходимости доливайте масло через вентиляционный патрубок.',
#    'Смажтье обычным солдомол обработанные поверхности станины, на которые будет опираться подшипниковый узел. Это поможет при установке рабочего колеса во время окончательной сборки.']},
#  {'answer': 'Вопрос не относится к содержанию документа. \n\n        Информация не найдена в dokumentе.',
#   'question': 'Назовите заводскую смазку, рекомендованную для камеры центробежного уплотнения.',
#   'sources': [{'chunk_id': 1,
#     'content': 'Описанная выше продецура подходит для установий деталей из мбкого ластомаре. КФестики же листалометре предварительно следует нареть в жаркой комнате или исслускеннев прочим теплого воздуха. Это обеспе...'},
#    {'chunk_id': 2,
#     'content': 'Для смазки камеры центробежного уплотнения рекомендуется использовать смазочные материалы с следующими характеристиками:'},
#    {'chunk_id': 3,
#     'content': '## Смазка центробежного уллотнения (если примененстя)',
#     'section': 'Смазка центробежного уллотнения (если примененстя)'},
#    {'chunk_id': 4,
#     'content': 'Установите дефректор и понадложайте за подшипниковым узлом примерно в течение 10 минут, чтобы бедиться, то он не течет. С влияние протеки проверите правильность сборки и уверения. Масл. Евниности необ...'},
#    {'chunk_id': 5,
#     'content': 'См. раздел WP6 "БСОРКА НАССОА" Массонов: Насосы с центробежным уплотнением снабжены металлическим корпусом экспледлера. Заполните смазкой камеру сточного чинотулогении. Рекомендуется два полных оборот...'}],
#   'relevant_chunks': ['Описанная выше продецура подходит для установий деталей из мбкого ластомаре. КФестики же листалометре предварительно следует нареть в жаркой комнате или исслускеннев прочим теплого воздуха. Это обеспечит достаточную мбкость деталей из гластомера перед сборкой.',
#    'Для смазки камеры центробежного уплотнения рекомендуется использовать смазочные материалы с следующими характеристиками:',
#    '## Смазка центробежного уллотнения (если примененстя)',
#    'Установите дефректор и понадложайте за подшипниковым узлом примерно в течение 10 минут, чтобы бедиться, то он не течет. С влияние протеки проверите правильность сборки и уверения. Масл. Евниности необходимость разбрать подшипник, проверите улотнения на предмет царизами и литан, которые могут сказаться на политичеством словъстей колец.',
#    'См. раздел WP6 "БСОРКА НАССОА" Массонов: Насосы с центробежным уплотнением снабжены металлическим корпусом экспледлера. Заполните смазкой камеру сточного чинотулогении. Рекомендуется два полных оборота крышки пресс-массилен.']},
#  {'answer': 'Вопрос не относится к содержанию документа. \n\n        Информация не найдена в dokumentе.',
#   'question': 'Приведите номер телефона сервисной линии для клиентов в Финляндии.',
#   'sources': [{'chunk_id': 1,
#     'content': 'Центровка - прямое соединение через ИУТФуИТЕЧЕНИЕ -'},
#    {'chunk_id': 2,
#     'content': '| SPARES & SUPPORT HELPLINES   | SPARES & SUPPORT HELPLINES   | SPARES & SUPPORT HELPLINES   |\n|------------------------------|------------------------------|------------------------------|\n| SALES OF...'},
#    {'chunk_id': 3,
#     'content': 'По желанию клинейта мы можем предложить в чида сервисного (технического) обслуживания:'},
#    {'chunk_id': 4,
#     'content': 'Для насосов стандартных размеров в большинстве случаев мы предлагаем услугим по замене установок. Чтобы воспользовать это услугом, Вам необходимо стваясь с нашим сервисным центром в г. Тодмордене (Вел...'},
#    {'chunk_id': 5,
#     'content': '- специалисты прибыляют на место в течение 24 часов после размещения заказа. Капитальный ремонт на заводе изготовителя'}],
#   'relevant_chunks': ['Центровка - прямое соединение через ИУТФуИТЕЧЕНИЕ -',
#    '| SPARES & SUPPORT HELPLINES   | SPARES & SUPPORT HELPLINES   | SPARES & SUPPORT HELPLINES   |\n|------------------------------|------------------------------|------------------------------|\n| SALES OFFICE                 | TELEPHONE                    | TELEPHONE                    |\n| Benelux                      | +31 77 3272 840              |                              |\n| Czech Republic               | +420 543 518 300             |                              |',
#    'По желанию клинейта мы можем предложить в чида сервисного (технического) обслуживания:',
#    'Для насосов стандартных размеров в большинстве случаев мы предлагаем услугим по замене установок. Чтобы воспользовать это услугом, Вам необходимо стваясь с нашим сервисным центром в г. Тодмордене (Великобритания) и детально обслужит требования, которые должны соблюдать для конкретного насоса.',
#    '- специалисты прибыляют на место в течение 24 часов после размещения заказа. Капитальный ремонт на заводе изготовителя']},
#  {'answer': 'Информация не найдена в documentation.',
#   'question': 'Какова ширина ремня (мм), указанная для диапазона шкивов 170-224 мм (профиль SPB)?',
#   'sources': [{'chunk_id': 1,
#     'content': 'Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмера рамы насоса:'},
#    {'chunk_id': 2,
#     'content': 'Установка внутренней части конического подшипника со стороны привода'},
#    {'chunk_id': 3,
#     'content': 'Попереч. Усилие, необходимо для стреты прогиба сечение 16 мм на 1 пролета'},
#    {'chunk_id': 4,
#     'content': 'Установка внутренней части конического подшипника со стороны рабочего колеса'},
#    {'chunk_id': 5,
#     'content': 'Установка наружного кольца подшипника со стороны привода'}],
#   'relevant_chunks': ['Рекомендуемое количество смазки в подшипниковом узле в зависимости от типоразмера рамы насоса:',
#    'Установка внутренней части конического подшипника со стороны привода',
#    'Попереч. Усилие, необходимо для стреты прогиба сечение 16 мм на 1 пролета',
#    'Установка внутренней части конического подшипника со стороны рабочего колеса',
#    'Установка наружного кольца подшипника со стороны привода']}]

# %%
documents
# Out:
# [Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 0, 'section': 'Installation, Operation &amp; Maintenance Manual', 'chunk_index': 0, 'total_chunks': 1}, page_content='## Installation, Operation &amp; Maintenance Manual'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 4, 'section': 'INSTALLATION, OPERATION &amp; MAINTENANCE MANUAL', 'chunk_index': 0, 'total_chunks': 1}, page_content='## INSTALLATION, OPERATION &amp; MAINTENANCE MANUAL'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 6, 'chunk_index': 0, 'total_chunks': 1}, page_content='| Client:      | Engineering Dobersek   |\n|--------------|------------------------|\n| Warman Ref:  | SAP171654              |\n| Serial No/s: | WP44549-60             |\n| Tag No/s:    |                        |\n| Manual Ref:  | WP946PD                |\n| Date:        | 31.07.08               |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 7, 'chunk_index': 0, 'total_chunks': 4}, page_content='| SPARES & SUPPORT HELPLINES   | SPARES & SUPPORT HELPLINES   | SPARES & SUPPORT HELPLINES   |\n|------------------------------|------------------------------|------------------------------|\n| SALES OFFICE                 | TELEPHONE                    | TELEPHONE                    |\n| Benelux                      | +31 77 3272 840              |                              |\n| Czech Republic               | +420 543 518 300             |                              |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 7, 'chunk_index': 1, 'total_chunks': 4}, page_content='| England                      | +44 1706 814251              |                              |\n| Finland                      | +358 3 877 350               |                              |\n| France                       | +33 4 72 8106 29             |                              |\n| Germany                      | +49 7131 640090              |                              |\n| Hungary                      | +36 34 314 794               |                              |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 7, 'chunk_index': 2, 'total_chunks': 4}, page_content='| Italy                        | +39 02 9242 341              |                              |\n| Poland                       | +48 632 8473                 |                              |\n| Romania                      | +40 259 465344               |                              |\n| Russia                       | +70 95 775 08 67             |                              |\n| Sweden                       | +46 920 870 77               |                              |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 7, 'chunk_index': 3, 'total_chunks': 4}, page_content='| Ukraine                      | +380 56 778 31 87            |                              |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 9, 'chunk_index': 0, 'total_chunks': 4}, page_content='| Раздел WP1   | Введение                                                                                                                                                           | WP1.01                                                     |\n|--------------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------|'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 9, 'chunk_index': 1, 'total_chunks': 4}, page_content='| Раздел WP2   | Установка и запуск                                                                                                                                                 | WP2.01, 02,  WP2.03, 04,  WP2.05, 06,  WP2.07, 08,  WP2.09 |\n| Раздел WP3   | Ежедневное обслуживание и устранение неполадок                                                                                                                     | WP3.01, 023,  WP3.04, 505                                  |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 9, 'chunk_index': 2, 'total_chunks': 4}, page_content='| Раздел WP4   | Сборка подшипникового узла                                                                                                                                         | WP4.113, 120,  WP4.130, 143                                |\n| Раздел WP5   | Сборка корпуса и станины                                                                                                                                           | WP5.110                                                    |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 9, 'chunk_index': 3, 'total_chunks': 4}, page_content='| Раздел WP6   | Сборка насоса                                                                                                                                                      | WP6.130                                                    |\n| Раздел WP7   | Установка улотнений вала Установка улотнений вала Установка деталей проточной части Установка деталей проточной части Регулировка переднего зазора рабочего колеса | WP6.150 WP6.170 WP6.190 WP6.200                            |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 18, 'section': 'С САЛЬНИКОВЫМ УПЛОТНЕНИЕ МЕТАЛОЛЯФОТЕРЫНАНЬНИМ (М. IMP)', 'chunk_index': 0, 'total_chunks': 1}, page_content='## С САЛЬНИКОВЫМ УПЛОТНЕНИЕ МЕТАЛОЛЯФОТЕРЫНАНЬНИМ (М. IMP)'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 20, 'chunk_index': 0, 'total_chunks': 1}, page_content='Данное руководство предназначено только для указанного типа насосов.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 21, 'chunk_index': 0, 'total_chunks': 1}, page_content='Дополнительные экземпляры руководства можно приобрести за отдельную плату, которую мы вынуждены взимать, чтобы покрыть типографские и административные расходы.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 22, 'chunk_index': 0, 'total_chunks': 1}, page_content='В результате постоянного усовершенствования оборудования некоторые запасные части могут отличаться от первоначально установленных деталей. Информация, изложенная в настоящем руководстве, базируется на данных, известных на момент последней редакции. Однако, мы оставляем за собой право модифицировать оборудование, что не всегда может быть отражено в руководстве.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 26, 'chunk_index': 0, 'total_chunks': 1}, page_content='Для того, чтобы обеспечить долговременную и беспереболную работу насоса Шаги, следует аккуратно соблюдать инструкции, изложенные в настоящем труководстве.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 27, 'chunk_index': 0, 'total_chunks': 1}, page_content='На станине каждого насоса Шагибиты его заводской номер и наблертификационный код.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 28, 'chunk_index': 0, 'total_chunks': 1}, page_content='Идентификационный код, насоса состоит из цифр и букв, расположенных в следующем порядке:'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 33, 'chunk_index': 0, 'total_chunks': 1}, page_content='Перед отправкой с завода насос и привода устанавливаются на общую раму. В процессе установки концы валов насоса и привода центруются.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 34, 'chunk_index': 0, 'total_chunks': 1}, page_content='Неровный фундамент на месте установки насоса может вызвать перекос рамы. Чтобы избежать перекоса, поверхность фундамента должна быть выровенна, как описано в разделе "Пригонка общей рамы".'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 36, 'chunk_index': 0, 'total_chunks': 1}, page_content='Добиться эффективной работы насоса можно только установив его на стальной или бетонный фундамент, сконструированный таким образом, чтобы снимать все нагружил с насоса и электродвигателя и гаситы любые видиряции.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 37, 'chunk_index': 0, 'total_chunks': 1}, page_content='Во время подготовки фундаментного блока в бетоне безо должны быть остальней ответствии для установки западных болтов. (Координаты указаны на неретехда общего вида).'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 38, 'chunk_index': 0, 'total_chunks': 1}, page_content='Поверхность фундаментного блока должна осталося необработанной для наиесення последнего слоя иементного раствора.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 39, 'section': 'Глубина фундамента должна соответствовать природе угрита.', 'chunk_index': 0, 'total_chunks': 1}, page_content='## Глубина фундамента должна соответствовать природе угрита.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 40, 'chunk_index': 0, 'total_chunks': 1}, page_content='Если станина насоса устанавливается непосредственно на стальную раму, то конструкция подследняю для быть достаточно прочной, чтобы выдержать нагрузку в процессе работы насоса и мсключить деформацию базовой рамы при установке насоса и станины.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 42, 'chunk_index': 0, 'total_chunks': 1}, page_content='Установите анкерные болты в отверстия на раме и заверните гайки на полную их высоту.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 43, 'chunk_index': 0, 'total_chunks': 1}, page_content='Установите раму с насосом и приводной частью на фундамент.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 44, 'chunk_index': 0, 'total_chunks': 1}, page_content='Такие крупногаяринтные узлы, как насос, редуктор, частотный преобразователь и электродвигатель, перед установкой настоятельно рекомендуется снять с рамы.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 45, 'chunk_index': 0, 'total_chunks': 2}, page_content='Между станином и блоком фундамента продолжите железные или стальные прокладки на небольшом расстоянии друг от фуга. Для того, чтобы установить раму без перекоса, воспондутьесть таким количеством прокладкой, како будет необходимо. Дополнительно следует положить по данной продолжидаке с кадкой стороны неэкраного болита. Проверьете уровневан установки рамы и отретуйте регистор по сперинбенность белое 0,05 мм на каждые 254 мм. Это делается при помощи регулировочных прокладок'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 45, 'chunk_index': 1, 'total_chunks': 2}, page_content='. Это делается при помощи регулировочных прокладок. Убедитель, что каждая прокладок предукравет раму.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 46, 'chunk_index': 0, 'total_chunks': 1}, page_content='Когда станина будет выровена, запечите анкерные болты жидким строительным раствором.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 47, 'chunk_index': 0, 'total_chunks': 1}, page_content='После того, как раствор схватиться, аккуратно, но крепко затяните анкерные болты. Для земле такосторою, чтобы не перекосив прокладу или не выровать анкерные болты из бетона.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 48, 'chunk_index': 0, 'total_chunks': 1}, page_content='Детал, которые предравительно были снаты с рамы, следует установить на место.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 49, 'chunk_index': 0, 'total_chunks': 1}, page_content='Проверьте центровку насоса и его приводной части. См. Раздел РИБ2 "ЦЕНТРОВКА".'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 50, 'chunk_index': 0, 'total_chunks': 1}, page_content='После того, как рама выровенна, а вал отцентрован, следует еще раз залить жидкий строительный раствор. Бетонное основание выполнено.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 51, 'section': 'Центровка и натяжение ременд Клиноременной передачи', 'chunk_index': 0, 'total_chunks': 1}, page_content='## Центровка и натяжение ременд Клиноременной передачи'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 53, 'chunk_index': 0, 'total_chunks': 1}, page_content='При ременной электродвигателя отцентрованы. Непараллельность износ ременд'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 69, 'chunk_index': 0, 'total_chunks': 1}, page_content='Прежде, чем установить ремни, выполните следующее. Общите пазы от ряжный и заследные.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 70, 'chunk_index': 0, 'total_chunks': 1}, page_content='Уменьшите расстояние между центрами валов двигателя и Насоса, подтягивая электродвигатель к насосу с помощью приглагаемых установочных болтов, да тож пока, рези примени вычаги в синутах вбить ради зашывов без учисли. Приложило на ступиной крупно личеку к торцам шиковов насоса электродвигателя. Отцентровые следует так, что бы не бы проспосред между линейкой и торцевыми поверхностями шиков, или чизе зазор допэки быть минимальным. См. рисунок 1.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 72, 'chunk_index': 0, 'total_chunks': 1}, page_content='Правильное натяжение ременд лередации беспочевай идопильн. срок службы, как ременд, так и роликовых подпишкинов. Натягивая ремень следует вращать придводя дго, чтобы натяжение было равномерным. Высокий КПД клиноременной передачи, соответствующий требованиями, предъявляемыми соорвеннему оборудованию, может быть достигнут только при правильному натяжении ременд. Для проверки правильности натяжения ремости рисунок 2 и выполните операции, приведенные далее.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 73, 'chunk_index': 0, 'total_chunks': 1}, page_content='- · Измерьте расстояние между центрами шиков (м)\n- · Приложите усилие под прямым углом к центру ремня, чтобы обеспечить его необходимый произв. Прогиб (мм) = Расстояние между шкивами (м) × 16\n- · Сравните требуемые усилие с величиной, приведенной в таблице.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 74, 'chunk_index': 0, 'total_chunks': 1}, page_content='Если измеренное усилие находится в пределах значения, указанного в таблице, то натяжение ремня считается удовлетворительным. Если усилие выше или ниже расчетного значения, то натяжение ремня должно быть увеличен или синжею соответственно.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 77, 'chunk_index': 0, 'total_chunks': 1}, page_content='Новые ремни иликонеменной передачи следует натягивать с большим усилием, чтобы скомпенсировать естественный спарт нажтяжения в время работы.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 78, 'chunk_index': 0, 'total_chunks': 1}, page_content='После получасового пробега натяжение должно быть измерено и заново увеличенно.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 80, 'chunk_index': 0, 'total_chunks': 1}, page_content='Попереч. Усилие, необходимо для стреты прогиба сечение 16 мм на 1 пролета'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 82, 'chunk_index': 0, 'total_chunks': 1}, page_content='SPZ 16 то 75 to 90 18 20 22 28 24 20 26 28 24 20 26 28'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 101, 'chunk_index': 0, 'total_chunks': 1}, page_content='Недостаточное натяжение ремнёнён вызывает вбирацю, в результате координой может возникнуть повреждение подпишкинового узла и спинжение передаточного оценительной. Такое возможно пракслывальные и перегрев, приводящий к снижению прочности ремня, с доследовательно, к сокращению срока службы.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 103, 'chunk_index': 0, 'total_chunks': 1}, page_content='Чрезмерное натяжение ремня передачи может привести к сокращению осрока его службы. Кроме того, подпишники могут перевраться из-за возрастищеного радиального усилия на вращающихся элементах, что приведет к предвредиется предвременному разрушению.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 107, 'chunk_index': 0, 'total_chunks': 1}, page_content='Центровка - прямое соединение через ИУТФуИТЕЧЕНИЕ -'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 109, 'chunk_index': 0, 'total_chunks': 1}, page_content='При прямом соединении через муфту неточность центровки может вызвать выбиращим изослочниким. следует избегать жестких муфт. Ухимершение возможно топью после консультации с представителями компаний Шипким и прямуки, представители этого мала,'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 110, 'chunk_index': 0, 'total_chunks': 1}, page_content='Операции, необходимые для проведений центровки вала, приведены в произвлики BS 3170 1972. Этот метод не зависит от точности посадки муфты на вал, и таким образом на него не влияют перекосы торцевых доверхнействами или эксцентричность надукостей муфты.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 111, 'chunk_index': 0, 'total_chunks': 1}, page_content='Предпреждение: УБЕЩЕСТВО, что ВПАР ПИВ ВРАШЕНИМ НЕ ЗАДЕВАЕР ДФУГИТЕДАЛИ.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 112, 'chunk_index': 0, 'total_chunks': 1}, page_content='Предлеже, чем начать центровку, проверите кафы в отдельности, чтобы будеться, что вал и подшижний рабочист без изишнего трения, и что бечение вала находится в пределах допуска 0,04 мм по шкале индикатора.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 113, 'chunk_index': 0, 'total_chunks': 1}, page_content='Полоповный муфты должны быть своденные с зазорам, чтобы иметь возможность равцаться относительно другий, анале показана индикатора не будут точными. Шипким и пружины, препятствующие свободному вращению полутном, эльный быле уланель. Показаний индикатора считываются топью токе посего, того, как линии, наченная поперек обежи полутдв, совмещена и Прямое изользований узбиатых муфт убедиться, что во время стремках из бакуловий ножа измерителя не проживается в казанку,'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 116, 'chunk_index': 0, 'total_chunks': 1}, page_content='Чьюбы обеспечить правильную центровку изола осей необходимо выполнить следующие опереций:'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 118, 'chunk_index': 0, 'total_chunks': 1}, page_content='Установите два индикатора на валем диаметрально протоположить точках (180°) на одной полутфуте, как показано на рисунке 3. Ножи индикатора должны быть зафиксированы на внутренней поверхности другой полутфуты.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 119, 'chunk_index': 0, 'total_chunks': 1}, page_content='Повокращайте муфту до тех пор, пока почнайкотары ни займут строго вертикальнее положение, установите стренку измерителя на ноль.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 120, 'chunk_index': 0, 'total_chunks': 1}, page_content='Поверните полутфуту на пол-оборота (180°) запишете показания клюкогдан и микатора. Потазаний должны быть иденты, что иннут могу не содвадать с нулевым яниезимень назом 3-вза озмобного отличнения концентра кала.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 121, 'chunk_index': 0, 'total_chunks': 1}, page_content='Примечивыми авляткая кол-покажительные, так и отрицательные показания при условии, что они будут совпадать на обоих индикаторах. В случае необходимости отрегулируйте одну из полутфут. Значения максимальных допусках уконазывалей "Допуска".'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 122, 'chunk_index': 0, 'total_chunks': 1}, page_content='Повокращайте муфту до тех пор, пока индикаторы ни займут строго горизонтальное положение, затем установите индикаторы измерителя на ноль.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 123, 'chunk_index': 0, 'total_chunks': 1}, page_content='При необходимости повторите эту оп ферацию несколько раз до тех пор, пока узеп ни займет положение в пределах разрешенного допуска.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 125, 'chunk_index': 0, 'total_chunks': 1}, page_content='Чтобы обеспечить правильную центровку по радиальному смещению осей необходимо выполнить следующие операции.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 127, 'chunk_index': 0, 'total_chunks': 1}, page_content='Установите один из индикаторов на одной половине муфты, при этом измерителя дополнялася показано на рисоком другой половины муфты. Установите измеритель индикатора на ноль.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 128, 'chunk_index': 0, 'total_chunks': 1}, page_content='Поверните положники муфты на четверть оборота (90°) и снимите показании индикаторов. Повортие процедуру через каждые 90°. Любое изменение показаний должно сказывает на отполнение от центрального положения. Следует отрегулировать положение одного из удал ток, чтобы показания цифрового индикатора через каждые 90° были идентичными или находились в предпаруси.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 129, 'chunk_index': 0, 'total_chunks': 1}, page_content='Примечание: Предарительная центровка может быть осуществлена и при охлажденном узле, однако следует принимать во внимание то, что при рабочей температуре ось одного из удал токов почта понятиясь по отношению к оси другого. После достижения насосом рабочей температуры необходимо произвести повторную центровку.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 132, 'chunk_index': 0, 'total_chunks': 1}, page_content='Пределы допусков, внутри которых должно производиться регулирование, ному быть четко определены из-за различий в размерах и скорости вращения узлов, однако при проверке центровки следует придежиряваться указанных ниже наченний.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 138, 'chunk_index': 0, 'total_chunks': 1}, page_content='Допуск не должен превышать 0.1 мм на мерной шкале микрометра (т.е. 0.05 ммк здекциитрситета).'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 144, 'chunk_index': 0, 'total_chunks': 2}, page_content='Любые нагрузки, действующие на корпус насоса со стороны трубопроводов, вызванные как весом труб, так и неправильной их установкой, недопустимы. Опыт показывает, что такие нагрузки могут серьезно нарушить центровку насоса. Все трубы, присоединяемые к насосам должны иметь правильные размеры и быть полностью поддерживаемыми. Контактные поверхности фланцев трубопровод и пригласивает друг к другу, при этом все отверстия для болтов должны находиться на одной нос'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 144, 'chunk_index': 1, 'total_chunks': 2}, page_content='. Присоединяя трубопровод к насосу, ни в коем случае не прикладывайте большие усилия, т.к. 3 тюж может привести к поврехдению корпусов и фланцев.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 145, 'chunk_index': 0, 'total_chunks': 1}, page_content='Съемная часть трубы (предполительно гибка со стороны всасывания) должна быть установлена на всасе и нагнетании трубопровода. Длина всей трубы на как тасе, как и на нагнетании должна быть достаточной для того, чтобы симать корпус и иметь доступ к насосу при замене изменених действало.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 146, 'chunk_index': 0, 'total_chunks': 1}, page_content='ВАКНО: ПРИ ИСПОЛЬЗОВАНИИ ЗЕМЛЕССОВИ О ГРАВИЙИНЫХ НАСОСОВ НА ПЛАВАЮЩИХ УСТАНОВАКИ КАК ВАССЫВАЮЩИ, ТАК И НАТЕНТЕЛЬНЫЙ ДНЫЦАНСЫ АОСЛИЖНЫЙ ВЫСОДЕНИЙ С ГИБКИМИ ТРУБЕАЛИ. ЭТО ОБЕОСИТЕЙ СТВОИБОНОЕ ДАНИЕНЕ ГИБЕРОПОВОД И ФИКСОРИВАННЫХ ФЛАНИЕВ НАСОСА. Более ГОТО, ЕСТЕСТВЕННЫЕ ВИБРАЦИИ, ПЕРЕДАВЕМЫЕ НА НАСОС, БУДТ ПОГОЛИТАТЬСЯ ГИБЕКИМИ ТРУБЕАЛИ:'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 148, 'chunk_index': 0, 'total_chunks': 1}, page_content='На всасывающей трубе максимально близко к насосу должна быть установлена отсечная завижка.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 149, 'chunk_index': 0, 'total_chunks': 1}, page_content='ВАССЫВАЮЩИЙ ТРУБОПРОВОД ДОЛЖЕН БыТь ЗАФИКСИРОВАН НА ВСЕМ СВОЕМ ПРОТЯКЕНИИ'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 150, 'chunk_index': 0, 'total_chunks': 1}, page_content='Всасывающая труба допжана быть предельно короткой. Не рекомендуется устанавливать общий всасывающий трубопровод для вихи и более насосов, работающих на'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 151, 'chunk_index': 0, 'total_chunks': 1}, page_content='водем. Если так усагажа неволяне бежня, то польбе точки возможности догодаху также, так сальники кланов, должны быть употенц. при помощи употняющей ключам, также а также в соответствующих местах должны быть установленной вироплушенное клапаники.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 152, 'chunk_index': 0, 'total_chunks': 1}, page_content='Диаметр всасывающей трубы зависит от ее длины и не привязан к диаметру всасывающего патрубка насоса. Размер трубой должен быть таким. чтобы скорость поток блина минимальной, но при этом первыша критическую скорость оседания твердых частиц, чтобы уменьшить потери на трение. Т.е. длиная всасывающая труба (или труба с большим количеством колен), пропускающая определенное количество жидкости, должна иметь больший внутренний диаметр, чем короткая прямая труба, пропускающая таке жо количество жидкости.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 153, 'chunk_index': 0, 'total_chunks': 1}, page_content='В случае, если внутренний диаметр всасывающей трубы увеличен до размера большего, чем диаметр всасывающего патрубка насоса, использование'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 155, 'chunk_index': 0, 'total_chunks': 1}, page_content='соединительной -трубы кончической формы не должно допустить образование воздушных пробоков.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 156, 'chunk_index': 0, 'total_chunks': 1}, page_content='Во избежание образования воздушных пробок установка всасывающей трубы должна отвечать следующим требованиям: (А) Минимальное количество колен (Абспонтая герметичность) конкусность внизум (см. рис. 5)'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 158, 'chunk_index': 0, 'total_chunks': 1}, page_content='В нанетательном трубопроводе максимально близко к насосу должна быть установлена отсечная задвижка. НАГНЕТАТЕЛЬНЫЙ ТРУБОПРОВОД ДОЛЖЕН БыТь'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 159, 'chunk_index': 0, 'total_chunks': 1}, page_content='ВАЖНО: ПРИ СОЕДИНЕНИИ ВАССЫВАЮЩЕГО И НАТЕНТЕЛЬНОГО ФЛАНИЕВ НАСОСА к ТРУБОПРОВОД НАСТОЯЕННОГО РЕКОЕНДУСТЕЙ СПИДНЫЙ УПТНОЛЬНЫЙ ПЕНТЛИНЫЕ КОЛЬЦИЯ ФИРМЬ НАГМАН. ТИКОЛЬЦИЯ ЯЛОБЛИТЫ НЕТОНИЕМ МЕНУКТУРУОЛОВОРОДСОВ'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 160, 'chunk_index': 0, 'total_chunks': 1}, page_content='ВАКНО: НЕ ПЕРГИЯВАГИФОТЫ ЭНАЦИЕВ, Т.К. ЭТО МОЖЕТЫ ВЫЗАВТОРЕНИЕ ПУТНОЛЕНЕЛЬНАЦЕ'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 161, 'chunk_index': 0, 'total_chunks': 1}, page_content='Уплотнительные кольца Баиман захимаются между футеровой насоса и филанцем трубы, как показано на рисунке Б. Таким образом, важным условием является применение всасывающих и нагнетательных фланцев трубов с нутерными диаметрами, соответствующими диаметрам свасывающих и нагнетательных патрубков насосов.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 166, 'chunk_index': 0, 'total_chunks': 1}, page_content='Прежде, чем ввести насос в эксплуатацию, или перед его запуском после капитального ремонта через все трубопроводы, соединенные с насосом, должна быть прокачена вода. Затем следует выполнить следующим комплекс мероприятий:'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 169, 'chunk_index': 0, 'total_chunks': 1}, page_content='ПРЕДУПРЕЖДЕНИЕ: ВАРЕШЕНИЕ В НАПРАВЛЕНИИ ПРОТОВЛОЛОЖНОМ УКАНАНИТОГО СНЕРИЛИ НА АССОЕ ПРИВЕДЕК К СИВНИЧАНИЛО РАБОГЕО КОЛЕСА С ВАЛА И К СЕРЬЕЗНОМ ГОВРЕЖДЕНИЮ НАССОА.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 170, 'chunk_index': 0, 'total_chunks': 1}, page_content='Включать двигатель, проверьте направление вращения в и случае необходимости изменене тего ак, чтобы вал насоса вращалась в направлении, указанном стреткой, изображенной на корпусе насоса или надолиниковом узле.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 171, 'chunk_index': 0, 'total_chunks': 1}, page_content='Установите ремни. Во время нагитавания ременд отцентруйте вал. См. Раздел WP2 "Центровка". Присоедините муфту вала.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 173, 'chunk_index': 0, 'total_chunks': 1}, page_content='Поревните вал вручную. Убедитель, что рабочее колесо вращается свободно внутри насоса. При плоябрь приняках задачи рабочее колесо дольно быть отрегулировано. См. раздел "РЕГЛИУРОВА ЗАОРОДЕКСООЙ ГЕДОЛЬНИЯ'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 174, 'chunk_index': 0, 'total_chunks': 1}, page_content='Уплотняющая вода должна постоянно поступать в сальник, как перед пуском, так и в процессе работы насоса.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 175, 'section': 'Проверка уплотнения вала - центробежное улотнение', 'chunk_index': 0, 'total_chunks': 1}, page_content='## Проверка уплотнения вала - центробежное улотнение'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 176, 'chunk_index': 0, 'total_chunks': 1}, page_content='См. раздел WP6 "БСОРКА НАССОА" Массонов: Насосы с центробежным уплотнением снабжены металлическим корпусом экспледлера. Заполните смазкой камеру сточного чинотулогении. Рекомендуется два полных оборота крышки пресс-массилен.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 178, 'chunk_index': 0, 'total_chunks': 1}, page_content='Центробежный насос не запускатся без заливки, и в случае, если расчетный напор не был достигнут при запуске, насос ледует немедленно остановить, устранить неполадики и перед повторным пуском заливть его заново.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 179, 'chunk_index': 0, 'total_chunks': 1}, page_content='Насосы, работающие при положительном напоре на всес:'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 180, 'chunk_index': 0, 'total_chunks': 1}, page_content='Для заливки насоса полностью откройте клатан, перекрывающий всасывающее отверстие.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 181, 'chunk_index': 0, 'total_chunks': 1}, page_content='Насосы, работающие при отримательном напоре на всес:'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 182, 'chunk_index': 0, 'total_chunks': 1}, page_content='Для заливки такого типа насосов обратительск п крилложению к настоящему руководству, содержащему подробную информацию о различных методах заливки.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 184, 'chunk_index': 0, 'total_chunks': 1}, page_content='Проверка уплотнения вала - сальниковое уплотнением поток; ограниченный поток; поток малого объема'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 185, 'chunk_index': 0, 'total_chunks': 1}, page_content='См. раздел ИРБ "СБОРКА НАССОА" Убедитесь, что имеется доступ уплотняющей воды в нужном объеме и под это соответствующим давлением. На насосах, перекаивающих пульту, давление должно быть приблизительно на 0.35 кг/см\' выше даниели нанетаний. Расход воды для сальникового углотнения должен соответствовать следующим значении'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 226, 'chunk_index': 0, 'total_chunks': 1}, page_content='Обычно перед началом работы на пулыве насос может непродолжительное время прокачивать воду.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 228, 'chunk_index': 0, 'total_chunks': 1}, page_content='Проверьте и подключите все синдагизационные системы, системы блокировки и любые другие защитные приборы, включенные в систему переданчивания.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 229, 'chunk_index': 0, 'total_chunks': 1}, page_content='Откройте все вспомогательные задвижим на входе и выходе системы охлаждения.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 230, 'chunk_index': 0, 'total_chunks': 1}, page_content='Убедитесь, что уплотнение вала пригодно к эксплуатации.'),
# ...
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 611, 'chunk_index': 0, 'total_chunks': 1}, page_content='находящейся на станине насоса. Список общих базовых номеров и кодов материалов приведен в табл. ИРЭ.02.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 612, 'chunk_index': 0, 'total_chunks': 1}, page_content='Weir Waman Limited одладает уникальной водом натождений надприедоким илиментами средства обслуживания на после предългарении не продельно низким ценам. Мы заинтересованы в предоставлении не только продукции фирмы, но в обеспечении ее последующего обслуживания, до деталей не доставок много дослуживания, до деталей.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 613, 'chunk_index': 0, 'total_chunks': 1}, page_content='В нашем производственном центре в г. Тодмордене к Вашим услугам, квалифицированный персонал обладающий богатым опытом и навыками, накопившимися более, из за 50 лет производства илимовых насосов.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 614, 'chunk_index': 0, 'total_chunks': 1}, page_content='По желанию клинейта мы можем предложить в чида сервисного (технического) обслуживания:'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 616, 'chunk_index': 0, 'total_chunks': 1}, page_content='- специалисты прибыляют на место в течение 24 часов после размещения заказа. Капитальный ремонт на заводе изготовителя'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 617, 'chunk_index': 0, 'total_chunks': 1}, page_content='- Замена запасный предложивание на договорных условиях Технического обслуживания'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 618, 'chunk_index': 0, 'total_chunks': 1}, page_content='По требованию илинета и при наличии всех необходимых запасных частей мы можем в течение 24 насос после размещения чазака занаправить к линету квалифицированных специалистов для ремонта оборудования.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 619, 'chunk_index': 0, 'total_chunks': 1}, page_content='Однако, самый полупривый в услуг средних нашак заказчиков -это ремонту оборудования в специализированных цехах на заводе изготовителей Ущей отрапять насосы на ремонту тлад, где производствамы образомы.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 620, 'chunk_index': 0, 'total_chunks': 1}, page_content='Калифицированным обслуживающим персоналом средствами и оригинальным запасными видами Братьями. Мы'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 621, 'chunk_index': 0, 'total_chunks': 1}, page_content='Для насосов стандартных размеров в большинстве случаев мы предлагаем услугим по замене установок. Чтобы воспользовать это услугом, Вам необходимо стваясь с нашим сервисным центром в г. Тодмордене (Великобритания) и детально обслужит требования, которые должны соблюдать для конкретного насоса.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 625, 'chunk_index': 0, 'total_chunks': 1}, page_content='Каждая деталь насоса Шагим именимает немановиена в  базовый номер из трех цифр. Детали с одинаковыми наименованием, независимо от размера или материала, имеют одинаковый базовый номер.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 626, 'chunk_index': 0, 'total_chunks': 1}, page_content='Имеется более трехсот различных базовых номеров, большинство из которых не относятся к изнашиваемый частим. В следующем списке содержатся правильные наименования и базовые номера деталей, которые наиболее вероятно могут заказываться как запасные дасти.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 630, 'chunk_index': 0, 'total_chunks': 6}, page_content='| Поддишник в сборе                       |   005 |\n|-----------------------------------------|-------|\n| Поддишник                               |   009 |\n| Девреца                                 |   013 |\n| Втулка  крышки                          |   017 |\n| Втулка  крышки                          |   018 |\n| Крышкиватка (2-полпастная, бездарная)   |   018 |\n| Набор регулировочных прокладок          |   021 |\n| Эксплереил                              |   025 |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 630, 'chunk_index': 1, 'total_chunks': 6}, page_content='| Колько эксплеилера                      |   028 |\n| Втулка  крышки корпуса                  |   036 |\n| Вкладышту втулки крышки корпуса         |   041 |\n| Втулка  крышки корпуса (половина)       |   043 |\n| Свалинык                                |   044 |\n| Крышки                                  |   052 |\n| Содечительное кольцо втулска            |   060 |\n| Стопорная гадка пабринита               |   061 |\n| Лабиринтное кольцо                      |   062 |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 630, 'chunk_index': 2, 'total_chunks': 6}, page_content='| Фондоране кольцо                        |   063 |\n| "О-бранзоне кольцо крыльчатики          |   064 |\n| Кольцо горловины                        |   067 |\n| Вал                                     |   073 |\n| Гипьза вала                             |   075 |\n| Сальник водотолнитый                    |   078 |\n| Втулка горловины                        |   083 |\n| Манкжета углотинтельная                 |   090 |\n| Кожух                                   |   092 |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 630, 'chunk_index': 3, 'total_chunks': 6}, page_content='| Порвещенное углотинтельное кольцо       |   108 |\n| "О-бранзоне кольцо вала                 |   109 |\n| Втулка центробежного насоса             |   110 |\n| Прокладка                               |   111 |\n| Вкладышту втулки крышки корпуса         |   112 |\n| Проставка вала                          |   117 |\n| Органичитель фондарного кольца          |   118 |\n| Уплотнительное кольцо втулки            |   122 |\n| Уплотнитель втулки центробежного насоса |   124 |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 630, 'chunk_index': 4, 'total_chunks': 6}, page_content='| Уплотнитель задены утвулки              |   125 |\n| Крышватка (5-полпастная, открытая)      |   127 |\n| Чашка                                   |   131 |\n| Соединительное кольцо выпуска           |   132 |\n| Крыливатка (5-лопастная, открытая)      |   147 |\n| Задняя втулка                           |   156 |\n| "О-бранзоне кольцо                      |   217 |\n| Кожух                                   |   222 |\n| Выпускной патрубок                      |   239 |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 630, 'chunk_index': 5, 'total_chunks': 6}, page_content='| Вал (певосторонний)                     |   254 |\n| Лабиринтное кольцо (правостороннее)     |   255 |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 632, 'chunk_index': 0, 'total_chunks': 1}, page_content='Примечание: Слиски запасных частей для отдельных насосов Шагим с указанием полного списка номеров деталей Шагим предоставляются компанией Шагим Limited по запросу.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 634, 'chunk_index': 0, 'total_chunks': 1}, page_content='Код материала применяется для всех деталей, изготовленных из стандартных материалов Шагим, для деталей, которые могут быть поставлены из разнообразных материалов.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 635, 'chunk_index': 0, 'total_chunks': 1}, page_content='Все коды материалов Шагим состоит из одной бужы с лувая Шартим: некоторые из наиболее часто встречающихся кодов и соответствующие им материалы следующие:'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 636, 'chunk_index': 0, 'total_chunks': 3}, page_content='| НАИМЕНОВАНИЕ МАТЕРИАЛА                  | КОД МАТЕРИАЛА   |\n|-----------------------------------------|-----------------|\n| Никель твердый  Хром высокий            | А03             |\n| Никель твердый  Типии 4                 | А05             |\n| Никель высокупорный  Магкая сталь ЕБЭБД | С02             |\n| Нерж. сталь 316  Егегации               | С23             |\n| Железо SG                               | С55             |\n| Железо SG с кадмивым  покрытием         | Ф24             |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 636, 'chunk_index': 1, 'total_chunks': 3}, page_content='| Магкая сталь  Магкая сталь очинкованная | Е05             |\n| Чугн                                    | Е62             |\n| Титан                                   | G02             |\n| Сплав Настellyo C                       | L04             |\n| РТЕФ                                    | Р03             |\n| РУС                                     | Р30             |\n| Кевлар                                  | Q21             |\n| Резина                                  | R26             |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 636, 'chunk_index': 2, 'total_chunks': 3}, page_content='| Nordel                                  | S01             |\n| Нитрии                                  | S10             |\n| Бутил                                   | S21             |\n| Хиланол                                 | S31             |\n| Неопрен (втулки и кривычатки)           | S42             |\n| Неопрен (уплотнители)                   | S43             |\n| ВИТОН                                   | S51             |\n| ЕНСКАРИИЧЕСКИИ ПОКРЫТИЕМ                | Z04             |'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 637, 'section': 'Схема подъема: Насос с приводом, расположенным по вертикали (CV)', 'chunk_index': 0, 'total_chunks': 1}, page_content='## Схема подъема: Насос с приводом, расположенным по вертикали (CV)'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 640, 'chunk_index': 0, 'total_chunks': 3}, page_content='- 1. На вышеприведенном расчёнке показан безопасный метод подъема насоса. Тем не менее, подъем насоса доктивных спользвания компетентным уметником, который знаком с нормами безопасности и практикой стропови. Однклеи уметь выбрать подходящее подъемное оборудование и затем применить его безопасным образом.\n- 2. Масса насоса приводится в его заводской табличке.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 640, 'chunk_index': 1, 'total_chunks': 3}, page_content='- 3. Расчетный центр тяжести насоса показан в руководстве по эксплуатации; положение центра тяжести может варьировать с вязви с технологическими изменениями. На вышеприведенном рисунке показано положение альтернативной точки подъема с учетом упомянутых изменений.\n- 4. Для обеспечения ровного подъема может потребоваться регулировка длины стропа.\n- 5. Использовать двухкольцевой строп, надеваемый удавкой, как указано на рисунке для предотвращения проскальзывания насоса.'),
#  Document(metadata={'source': '/content/Руководство по насосам шламовым 4 DY -AHF.pdf', 'filename': 'Руководство по насосам шламовым 4 DY -AHF.pdf', 'format': 'pdf', 'converter': 'VLM Docling', 'section_index': 640, 'chunk_index': 2, 'total_chunks': 3}, page_content='- 6. Использовать в указанных случаях мягкие стропы в избежание повреждения насоса.\n- 7. В случае насосов, смачиваемая часть которых располагается ниже или выше низа основания, потребуется установка подпорки под смачиваемой частью во избежание опрокидывания насосов до того, как они будут закреплены на фундаменте.\n- 8. Места строповки на отдельных частях насоса предназначены для подъема только этих частей и не рассчитаны на полный вес насоса.')]
